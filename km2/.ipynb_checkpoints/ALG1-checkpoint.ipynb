# %%
import random
a = 100
b = 100
random.random()*(b-a)+a
# Out:
# 100.0

# %%
3a1 = 0.06981
a2 = 0.66322
b1 = 0.24434
b2 = 0.34906
r = 6378.137
import math
x = math.atan(math.sqrt(math.pow(math.cos(a2)*math.sin(b2-b1),2)+math.pow((math.cos(a1)*math.sin(a2)-math.sin(a1)*math.cos(a2)*math.cos(b2-b1)),2))/(math.sin(a1)*math.sin(a2)+math.cos(a1)*math.cos(a2)*math.cos(b2-b1)))
d = x*r
print (d)
# Out:
# 3833.6914983466513
