# %%
import sys
year = 2025
#year = int(sys.argv[2])
with open(sys.argv[1], 'r') as f:
    readlines()
    for line in f:
        for word in line.lower().split():
            if word == year:
                k += 1
print(k)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 3
#       1 import sys
#       2 year = 2025
# ----> 3 year = int(sys.argv[2])
#       4 with open(sys.argv[1], 'r') as f:
#       5     readlines()
#
# ValueError: invalid literal for int() with base 10: 'C:\\Users\\Sasha\\AppData\\Roaming\\jupyter\\runtime\\kernel-3d099b4f-c2d6-405a-8895-67120fb4a1d9.json'
